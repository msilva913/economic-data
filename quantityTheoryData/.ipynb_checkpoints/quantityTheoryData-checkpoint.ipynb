# %%
from __future__ import division
# %matplotlib inline
import numpy as np
import pandas as pd
import wbdata
import runProcs
import qtyTheoryFunc as qt
# if wbdata fails to load run in the shell: rm -r ~/.cache/wbdata

# %%
# 1. Get the World Bank ISO codes
isoCodes = pd.DataFrame(wbdata.search_countries("",display=False))
isoCodes = isoCodes[['id','name']]
isoCodes = isoCodes.set_index('name')

# %%
# 2. Indices for data series and labels for data frame

indicators = {'FP.CPI.TOTL': 'inflation rate',
              'FM.LBL.MONY.CN': 'money growth', 
              'NY.GDP.MKTP.KD': 'real gdp growth'
              }

# %%
# 3. Create the data frames with raw money, price level, and real gdp data from WB

# 3.1 country groups
countries =  [i['id'] for i in wbdata.get_country(incomelevel=['LIC','MIC','HIC'],display=False)]
countriesH = [i['id'] for i in wbdata.get_country(incomelevel=['HIC'],display=False)]
countriesM = [i['id'] for i in wbdata.get_country(incomelevel=['MIC'],display=False)]
countriesL = [i['id'] for i in wbdata.get_country(incomelevel=['LIC'],display=False)]

# 3.2 data frames
df   = wbdata.get_dataframe(indicators, country=countries,convert_date=True)
hicDf = wbdata.get_dataframe(indicators, country=countriesH,convert_date=True)
micDf = wbdata.get_dataframe(indicators, country=countriesM,convert_date=True)
licDf = wbdata.get_dataframe(indicators, country=countriesL,convert_date=True)

# %%
# 4. Create data sets of money growth, inflation, and real gdp growth
qtyTheoryData, include, dropped = qt.create(dataFrame=df,indicators=indicators,isoCodes=isoCodes,levels=[''],csvFilename='qtyTheoryData',decimals=5)
qtyTheoryDataH, includeH, droppedH = qt.create(dataFrame=hicDf,indicators=indicators,isoCodes=isoCodes,levels=[''],csvFilename='qtyTheoryDataH',decimals=5)
qtyTheoryDataM, includeM, droppedM = qt.create(dataFrame=micDf,indicators=indicators,isoCodes=isoCodes,levels=[''],csvFilename='qtyTheoryDataM',decimals=5)
qtyTheoryDataL, includeL, droppedL = qt.create(dataFrame=licDf,indicators=indicators,isoCodes=isoCodes,levels=[''],csvFilename='qtyTheoryDataL',decimals=5)
# Out:
# At least one series missing for American Samoa
# At least one series missing for Andorra
# At least one series missing for Argentina
# At least one series missing for Aruba
# At least one series missing for Austria
# At least one series missing for Azerbaijan
# At least one series missing for Bahamas, The
# At least one series missing for Bahrain
# At least one series missing for Belarus
# At least one series missing for Belgium
# At least one series missing for Benin
# At least one series missing for Bermuda
# At least one series missing for Burkina Faso
# At least one series missing for Cayman Islands
# At least one series missing for Channel Islands
# At least one series missing for China
# At least one series missing for Comoros
# At least one series missing for Cote d'Ivoire
# At least one series missing for Cuba
# At least one series missing for Curacao
# At least one series missing for Cyprus
# At least one series missing for Djibouti
# At least one series missing for Ecuador
# At least one series missing for El Salvador
# At least one series missing for Eritrea
# At least one series missing for Estonia
# At least one series missing for Ethiopia
# At least one series missing for Faeroe Islands
# At least one series missing for Finland
# At least one series missing for France
# At least one series missing for French Polynesia
# At least one series missing for Germany
# At least one series missing for Greece
# At least one series missing for Greenland
# At least one series missing for Guam
# At least one series missing for Guinea
# At least one series missing for Guinea-Bissau
# At least one series missing for Hong Kong SAR, China
# At least one series missing for India
# At least one series missing for Iran, Islamic Rep.
# At least one series missing for Ireland
# At least one series missing for Isle of Man
# At least one series missing for Italy
# At least one series missing for Jordan
# At least one series missing for Kiribati
# At least one series missing for Korea, Dem. Rep.
# At least one series missing for Kosovo
# At least one series missing for Kyrgyz Republic
# At least one series missing for Lao PDR
# At least one series missing for Latvia
# At least one series missing for Lebanon
# At least one series missing for Liberia
# At least one series missing for Libya
# At least one series missing for Liechtenstein
# At least one series missing for Lithuania
# At least one series missing for Luxembourg
# At least one series missing for Madagascar
# At least one series missing for Malawi
# At least one series missing for Mali
# At least one series missing for Malta
# At least one series missing for Marshall Islands
# At least one series missing for Mauritania
# At least one series missing for Micronesia, Fed. Sts.
# At least one series missing for Monaco
# At least one series missing for Montenegro
# At least one series missing for Myanmar
# At least one series missing for Netherlands
# At least one series missing for New Caledonia
# At least one series missing for New Zealand
# At least one series missing for Niger
# At least one series missing for Northern Mariana Islands
# At least one series missing for Norway
# At least one series missing for Palau
# At least one series missing for Panama
# At least one series missing for Peru
# At least one series missing for Portugal
# At least one series missing for Puerto Rico
# At least one series missing for Rwanda
# At least one series missing for San Marino
# At least one series missing for Saudi Arabia
# At least one series missing for Senegal
# At least one series missing for Singapore
# At least one series missing for Sint Maarten (Dutch part)
# At least one series missing for Slovak Republic
# At least one series missing for Slovenia
# At least one series missing for Somalia
# At least one series missing for South Sudan
# At least one series missing for Spain
# At least one series missing for Sri Lanka
# At least one series missing for St. Martin (French part)
# At least one series missing for Switzerland
# At least one series missing for Tajikistan
# At least one series missing for Timor-Leste
# At least one series missing for Togo
# At least one series missing for Tunisia
# At least one series missing for Turkmenistan
# At least one series missing for Turks and Caicos Islands
# At least one series missing for Tuvalu
# At least one series missing for United Arab Emirates
# At least one series missing for United Kingdom
# At least one series missing for United States
# At least one series missing for Uzbekistan
# At least one series missing for Vietnam
# At least one series missing for Virgin Islands (U.S.)
# At least one series missing for West Bank and Gaza
# At least one series missing for Yemen, Rep.
# At least one series missing for Zimbabwe
# At least one series missing for Andorra
# At least one series missing for Argentina
# At least one series missing for Aruba
# At least one series missing for Austria
# At least one series missing for Bahamas, The
# At least one series missing for Bahrain
# At least one series missing for Belgium
# At least one series missing for Bermuda
# At least one series missing for Cayman Islands
# At least one series missing for Channel Islands
# At least one series missing for Curacao
# At least one series missing for Cyprus
# At least one series missing for Estonia
# At least one series missing for Faeroe Islands
# At least one series missing for Finland
# At least one series missing for France
# At least one series missing for French Polynesia
# At least one series missing for Germany
# At least one series missing for Greece
# At least one series missing for Greenland
# At least one series missing for Guam
# At least one series missing for Hong Kong SAR, China
# At least one series missing for Ireland
# At least one series missing for Isle of Man
# At least one series missing for Italy
# At least one series missing for Latvia
# At least one series missing for Liechtenstein
# At least one series missing for Lithuania
# At least one series missing for Luxembourg
# At least one series missing for Malta
# At least one series missing for Monaco
# At least one series missing for Netherlands
# At least one series missing for New Caledonia
# At least one series missing for New Zealand
# At least one series missing for Northern Mariana Islands
# At least one series missing for Norway
# At least one series missing for Portugal
# At least one series missing for Puerto Rico
# At least one series missing for San Marino
# At least one series missing for Saudi Arabia
# At least one series missing for Singapore
# At least one series missing for Sint Maarten (Dutch part)
# At least one series missing for Slovak Republic
# At least one series missing for Slovenia
# At least one series missing for Spain
# At least one series missing for St. Martin (French part)
# At least one series missing for Switzerland
# At least one series missing for Turks and Caicos Islands
# At least one series missing for United Arab Emirates
# At least one series missing for United Kingdom
# At least one series missing for United States
# At least one series missing for Virgin Islands (U.S.)
# At least one series missing for American Samoa
# At least one series missing for Azerbaijan
# At least one series missing for Belarus
# At least one series missing for China
# At least one series missing for Cote d'Ivoire
# At least one series missing for Cuba
# At least one series missing for Djibouti
# At least one series missing for Ecuador
# At least one series missing for El Salvador
# At least one series missing for India
# At least one series missing for Iran, Islamic Rep.
# At least one series missing for Jordan
# At least one series missing for Kiribati
# At least one series missing for Kosovo
# At least one series missing for Kyrgyz Republic
# At least one series missing for Lao PDR
# At least one series missing for Lebanon
# At least one series missing for Libya
# At least one series missing for Marshall Islands
# At least one series missing for Mauritania
# At least one series missing for Micronesia, Fed. Sts.
# At least one series missing for Montenegro
# At least one series missing for Myanmar
# At least one series missing for Palau
# At least one series missing for Panama
# At least one series missing for Peru
# At least one series missing for Senegal
# At least one series missing for Sri Lanka
# At least one series missing for Tajikistan
# At least one series missing for Timor-Leste
# At least one series missing for Tunisia
# At least one series missing for Turkmenistan
# At least one series missing for Tuvalu
# At least one series missing for Uzbekistan
# At least one series missing for Vietnam
# At least one series missing for West Bank and Gaza
# At least one series missing for Yemen, Rep.
# At least one series missing for Benin
# At least one series missing for Burkina Faso
# At least one series missing for Comoros
# At least one series missing for Eritrea
# At least one series missing for Ethiopia
# At least one series missing for Guinea
# At least one series missing for Guinea-Bissau
# At least one series missing for Korea, Dem. Rep.
# At least one series missing for Liberia
# At least one series missing for Madagascar
# At least one series missing for Malawi
# At least one series missing for Mali
# At least one series missing for Niger
# At least one series missing for Rwanda
# At least one series missing for Somalia
# At least one series missing for South Sudan
# At least one series missing for Togo
# At least one series missing for Zimbabwe
# /Users/bcjenkin/Dropbox/GitHub/economicData/quantityTheoryData/qtyTheoryFunc.py:33: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   for index, row in newDf.sort(ascending=False).iterrows():

# %%
qtyTheoryDataM
# Out:
#                                iso code  observations  inflation rate  \
# Albania                             ALB            14         0.02791
# Algeria                             DZA            14         0.03915
# Armenia                             ARM            14         0.04599
# Bangladesh                          BGD            14         0.07170
# Belize                              BLZ            14         0.02136
# Bhutan                              BTN            14         0.04056
# Bolivia                             BOL            14         0.05552
# Bosnia and Herzegovina              BIH            10         0.02360
# Botswana                            BWA            14         0.08086
# Brazil                              BRA            14         0.06477
# Bulgaria                            BGR            14         0.04498
# Cabo Verde                          CPV            14         0.02244
# Cameroon                            CMR            14         0.02387
# Colombia                            COL            14         0.04544
# Congo, Rep.                         COG            14         0.03616
# Costa Rica                          CRI            14         0.08535
# Dominica                            DMA            14         0.01956
# Dominican Republic                  DOM            14         0.10121
# Egypt, Arab Rep.                    EGY            14         0.09044
# Fiji                                FJI            14         0.03534
# Gabon                               GAB            14         0.02111
# Georgia                             GEO            14         0.05141
# Ghana                               GHA            13         0.13804
# Grenada                             GRD            14         0.02379
# Guatemala                           GTM            14         0.06019
# Guyana                              GUY            13         0.05303
# Honduras                            HND            14         0.06882
# Indonesia                           IDN            14         0.07415
# Iraq                                IRQ            11         0.10578
# Jamaica                             JAM            14         0.10734
# ...                                 ...           ...             ...
# Maldives                            MDV            10         0.06929
# Mauritius                           MUS            14         0.05365
# Mexico                              MEX            14         0.04289
# Moldova                             MDA            14         0.08254
# Mongolia                            MNG            14         0.09761
# Morocco                             MAR            14         0.01686
# Namibia                             NAM            13         0.05913
# Nicaragua                           NIC            14         0.07990
# Nigeria                             NGA            14         0.11478
# Pakistan                            PAK            14         0.09336
# Papua New Guinea                    PNG            14         0.05815
# Paraguay                            PRY            14         0.06919
# Philippines                         PHL            14         0.04292
# Romania                             ROU            14         0.07851
# Samoa                               WSM            14         0.04644
# Sao Tome and Principe               STP            14         0.14767
# Serbia                              SRB            14         0.09880
# Solomon Islands                     SLB            14         0.07760
# South Africa                        ZAF            14         0.05891
# St. Lucia                           LCA            14         0.02459
# St. Vincent and the Grenadines      VCT            14         0.02847
# Sudan                               SDN            14         0.15929
# Suriname                            SUR            14         0.09474
# Swaziland                           SWZ            14         0.07034
# Thailand                            THA            14         0.02716
# Tonga                               TON            14         0.06064
# Turkey                              TUR            14         0.12375
# Ukraine                             UKR            14         0.09131
# Vanuatu                             VUT            14         0.02296
# Zambia                              ZMB            14         0.12309
#
#                                 money growth  real gdp growth
# Albania                              0.09110          0.04183
# Algeria                              0.16844          0.03680
# Armenia                              0.16266          0.06804
# Bangladesh                           0.14977          0.05825
# Belize                               0.10107          0.03491
# Bhutan                               0.17960          0.07620
# Bolivia                              0.19526          0.04560
# Bosnia and Herzegovina               0.07465          0.02091
# Botswana                             0.14186          0.05019
# Brazil                               0.11973          0.03363
# Bulgaria                             0.13448          0.03436
# Cabo Verde                           0.07888          0.04949
# Cameroon                             0.10277          0.03750
# Colombia                             0.13545          0.04555
# Congo, Rep.                          0.19453          0.04617
# Costa Rica                           0.15883          0.04546
# Dominica                             0.06009          0.02117
# Dominican Republic                   0.16433          0.04961
# Egypt, Arab Rep.                     0.16826          0.04087
# Fiji                                 0.14760          0.01862
# Gabon                                0.11505          0.02746
# Georgia                              0.19692          0.06074
# Ghana                                0.28485          0.07009
# Grenada                              0.05451          0.02110
# Guatemala                            0.11369          0.03549
# Guyana                               0.13627          0.03189
# Honduras                             0.11321          0.04030
# Indonesia                            0.13424          0.05500
# Iraq                                 0.19514          0.05901
# Jamaica                              0.12991          0.00590
# ...                                      ...              ...
# Maldives                             0.16369          0.07202
# Mauritius                            0.16939          0.03772
# Mexico                               0.12667          0.02312
# Moldova                              0.20140          0.04976
# Mongolia                             0.24108          0.08495
# Morocco                              0.09407          0.04393
# Namibia                              0.14966          0.05289
# Nicaragua                            0.19293          0.03526
# Nigeria                              0.17933          0.08095
# Pakistan                             0.17691          0.04262
# Papua New Guinea                     0.19605          0.05633
# Paraguay                             0.18292          0.04357
# Philippines                          0.14607          0.05248
# Romania                              0.19989          0.03508
# Samoa                                0.09523          0.02111
# Sao Tome and Principe                0.21748          0.05137
# Serbia                               0.21520          0.03084
# Solomon Islands                      0.20392          0.04495
# South Africa                         0.11043          0.03159
# St. Lucia                            0.08710          0.01640
# St. Vincent and the Grenadines       0.05243          0.02334
# Sudan                                0.24727          0.04836
# Suriname                             0.21125          0.04479
# Swaziland                            0.14536          0.02402
# Thailand                             0.08652          0.04160
# Tonga                                0.09575          0.00897
# Turkey                               0.26778          0.04830
# Ukraine                              0.23697          0.02444
# Vanuatu                              0.10242          0.03086
# Zambia                               0.19876          0.07302
#
# [65 rows x 5 columns]

# %%
# 6. Verify output 
print('Number of countries:',len(include),'\n')
print(qtyTheoryData.loc['United States'])
print(qtyTheoryData.loc['Germany'])
# Out:
# Number of countries: 99
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/bcjenkin/anaconda/lib/python3.4/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1324                 if not key in ax:
# -> 1325                     error()
#    1326             except (TypeError) as e:
#
# /Users/bcjenkin/anaconda/lib/python3.4/site-packages/pandas/core/indexing.py in error()
#    1319                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1320                                (key, self.obj._get_axis_name(axis)))
#    1321
#
# KeyError: 'the label [United States] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-9aaaef60aa0b> in <module>()
#       1 # 6. Verify output
#       2 print('Number of countries:',len(include),'\n')
# ----> 3 print(qtyTheoryData.loc['United States'])
#       4 print(qtyTheoryData.loc['Germany'])
#
# /Users/bcjenkin/anaconda/lib/python3.4/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1225             return self._getitem_tuple(key)
#    1226         else:
# -> 1227             return self._getitem_axis(key, axis=0)
#    1228
#    1229     def _getitem_axis(self, key, axis=0):
#
# /Users/bcjenkin/anaconda/lib/python3.4/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1369
#    1370         # fall thru to straight lookup
# -> 1371         self._has_valid_type(key, axis)
#    1372         return self._get_label(key, axis=axis)
#    1373
#
# /Users/bcjenkin/anaconda/lib/python3.4/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1331                 raise
#    1332             except:
# -> 1333                 error()
#    1334
#    1335         return True
#
# /Users/bcjenkin/anaconda/lib/python3.4/site-packages/pandas/core/indexing.py in error()
#    1318                         "cannot use label indexing with a null key")
#    1319                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1320                                (key, self.obj._get_axis_name(axis)))
#    1321
#    1322             try:
#
# KeyError: 'the label [United States] is not in the [index]'

# %%
# 7. Export notebook to python script
runProcs.exportNb('quantityTheoryData')
